# %% [markdown]
# # Esto es un trasteo del trabajo a realizar de limpieza y visualización de datos

# %% [markdown]
# ## Vamos a cargar el CSV sobre Población Activa en España
#  El objetivo de esto es analizar a la población Española, concretamente con los CSV´S de educación quiero ver 1º el nivel de estudios medios que tenia la poblacion en un año concreto y ver su variacion y en 2º lugar me gustaría ver cuantas personas dejan sus estudios para meterse a trabajar y si el CSV lo permite ver que nivel de estudios tenian en esos momentos.

# %%
pip install seaborn
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df_pob_act = pd.read_csv('C:/Users/Ro/OneDrive/Escritorio/No se como llamarlo/Ironhack/L L remoto/Group-7/Poblacion_Activa.csv', sep = ';')

# %% [markdown]
# Hay CSV´s que te pueden llegar a dar problemas a la hora de cargarlos, para arreglarlo debes mirar cómo están escritos y de ser necesario indicarle a Python/Pandas cómo debe separarlos. Para ello debes poner sep = 'el separador que debe usar'

# %% [markdown]
# ## CSV´s sobre educación

# %%
df_niv_est = pd.read_csv('C:/Users/Ro/OneDrive/Escritorio/No se como llamarlo/Ironhack/L L remoto/Group-7/niv_form.csv', sep = ';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_niv_est = pd.read_csv('C:/Users/Ro/OneDrive/Escritorio/No se como llamarlo/Ironhack/L L remoto/Group-7/niv_form.csv', sep = ';')
#
# ...

# %%
df_abandono_l = pd.read_csv('C:/Users/Ro/Downloads/aban_1_01bsc.csv', sep = ';')

# %%
print(f"La tabla de estudios de la poblacion es \n{df_pob_act.info()}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30800 entries, 0 to 30799
# Data columns (total 5 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Comunidad autónoma                                  30800 non-null  object
#  1   Relación con la actividad en el trimestre actual    30800 non-null  object
#  2   Relación con la actividad en el trimestre anterior  30800 non-null  object
#  3   Periodo                                             30800 non-null  object
#  4   Total                                               30800 non-null  object
# dtypes: object(5)
# memory usage: 1.2+ MB
# La tabla de estudios de la poblacion es
# None

# %%
print(f"La tabla de nivel de estudios es{df_niv_est.columns}")
print(f"La tabla de abandonos de estudios es{df_abandono_l.columns}")
# Out:
# La tabla de nivel de estudios esIndex(['Grupo de edad', 'Comunidad autonoma', 'Sexo', 'Nivel de formacion',
#        'periodo', 'Total'],
#       dtype='object')
# La tabla de abandonos de estudios esIndex(['Comunidad autonoma', 'Sexo', 'periodo', 'Total'], dtype='object')

# %%
print(f"En la tabla de nivel de estudios podemos encontrar {df_niv_est.nunique}")
# Out:
# En la tabla de nivel de estudios podemos encontrar <bound method DataFrame.nunique of      Grupo de edad Comunidad autonoma     Sexo  \
# 0     25 - 64 años              TOTAL  Hombres
# 1     25 - 64 años              TOTAL  Hombres
# 2     25 - 64 años              TOTAL  Hombres
# 3     25 - 64 años              TOTAL  Hombres
# 4     25 - 64 años              TOTAL  Hombres
# ...            ...                ...      ...
# 3775  55 - 64 años          - Melilla  Mujeres
# 3776  55 - 64 años          - Melilla  Mujeres
# 3777  55 - 64 años          - Melilla  Mujeres
# 3778  55 - 64 años          - Melilla  Mujeres
# 3779  55 - 64 años          - Melilla  Mujeres
#
#                         Nivel de formacion  periodo  Total
# 0     Inferior a 2ª etapa de E. Secundaria     2023  39,16
# 1     Inferior a 2ª etapa de E. Secundaria     2022  39,62
# 2     Inferior a 2ª etapa de E. Secundaria     2021  39,94
# 3     Inferior a 2ª etapa de E. Secundaria     2020  40,23
# ...

# %%
print(f"En la tabla de nivel de estudios podemos encontrar {df_abandono_l.nunique}")
# Out:
# En la tabla de nivel de estudios podemos encontrar <bound method DataFrame.nunique of     Comunidad autonoma     Sexo  periodo  Total
# 0                TOTAL  Hombres     2023  16,03
# 1                TOTAL  Hombres     2022  16,68
# 2                TOTAL  Hombres     2021  16,70
# 3                TOTAL  Hombres     2020  20,22
# 4                TOTAL  Hombres     2019  21,39
# ..                 ...      ...      ...    ...
# 235        Melilla (3)  Mujeres     2022     ..
# 236        Melilla (3)  Mujeres     2021     ..
# 237        Melilla (3)  Mujeres     2020     ..
# 238        Melilla (3)  Mujeres     2019     ..
# 239        Melilla (3)  Mujeres     2018     ..
#
# [240 rows x 4 columns]>

# %% [markdown]
# ## A partir de aquí se categoriza por sexos

# %%
df_abandono_l_muj = df_abandono_l[df_abandono_l['Sexo'] == 'Mujeres']
df_abandono_l_hom = df_abandono_l[df_abandono_l['Sexo'] == 'Hombres']

# %%
df_niv_est_muj = df_niv_est[df_niv_est['Sexo'] == 'Mujeres']
df_niv_est_hom = df_niv_est[df_niv_est['Sexo'] == 'Hombres']
print(df_niv_est_hom)
# Out:
#      Grupo de edad Comunidad autonoma     Sexo  \
# 0     25 - 64 años              TOTAL  Hombres
# 1     25 - 64 años              TOTAL  Hombres
# 2     25 - 64 años              TOTAL  Hombres
# 3     25 - 64 años              TOTAL  Hombres
# 4     25 - 64 años              TOTAL  Hombres
# ...            ...                ...      ...
# 3757  55 - 64 años          - Melilla  Hombres
# 3758  55 - 64 años          - Melilla  Hombres
# 3759  55 - 64 años          - Melilla  Hombres
# 3760  55 - 64 años          - Melilla  Hombres
# 3761  55 - 64 años          - Melilla  Hombres
#
#                         Nivel de formacion  periodo  Total
# 0     Inferior a 2ª etapa de E. Secundaria     2023  39,16
# 1     Inferior a 2ª etapa de E. Secundaria     2022  39,62
# 2     Inferior a 2ª etapa de E. Secundaria     2021  39,94
# 3     Inferior a 2ª etapa de E. Secundaria     2020  40,23
# 4     Inferior a 2ª etapa de E. Secundaria     2019  41,69
# ...

# %% [markdown]
# ## Valores extremos por df

# %%
print(f"La tasa más alta de abandono de estudios de la población masculina \n {df_abandono_l_hom.max()} \n los de la población femenina \n {df_abandono_l_muj.max()}")
# Out:
# La tasa más alta de abandono de estudios de la población masculina
#  Comunidad autonoma      TOTAL
# Sexo                  Hombres
# periodo                  2023
# Total                    9,43
# dtype: object
#  los de la población femenina
#  Comunidad autonoma      TOTAL
# Sexo                  Mujeres
# periodo                  2023
# Total                    9,96
# dtype: object

# %%
print(f"La tasa más baja de abandono de la población masculina fue \n {df_abandono_l_hom.min()} \n los de la población femenina \n {df_abandono_l_muj.min()}")
# Out:
# La tasa más baja de abandono de la población masculina fue
#  Comunidad autonoma    Andalucia
# Sexo                    Hombres
# periodo                    2018
# Total                        ..
# dtype: object
#  los de la población femenina
#  Comunidad autonoma    Andalucia
# Sexo                    Mujeres
# periodo                    2018
# Total                        ..
# dtype: object

# %%
print(f"La tasa más alta de abandono de estudios de la población masculina \n {df_niv_est_hom.max()} \n los de la población femenina \n {df_niv_est_muj.max()}")
# Out:
# La tasa más alta de abandono de estudios de la población masculina
#  Grupo de edad                                 55 - 64 años
# Comunidad autonoma                                   TOTAL
# Sexo                                               Hombres
# Nivel de formacion    Inferior a 2ª etapa de E. Secundaria
# periodo                                               2023
# Total                                                69,72
# dtype: object
#  los de la población femenina
#  Grupo de edad                                 55 - 64 años
# Comunidad autonoma                                   TOTAL
# Sexo                                               Mujeres
# Nivel de formacion    Inferior a 2ª etapa de E. Secundaria
# periodo                                               2023
# Total                                                71,88
# dtype: object

# %%
print(f"El nivel más bajo de estudios del que tenemos registros de la población masculina fue \n {df_niv_est_hom.min()} \n y de la población femenina \n {df_niv_est_muj.min()}")
# Out:
# El nivel más bajo de estudios del que tenemos registros de la población masculina fue
#  Grupo de edad                   25 - 34 años
# Comunidad autonoma                   - Ceuta
# Sexo                                 Hombres
# Nivel de formacion    2ª etapa E. Secundaria
# periodo                                 2018
# Total                                     ..
# dtype: object
#  y de la población femenina
#  Grupo de edad                   25 - 34 años
# Comunidad autonoma                   - Ceuta
# Sexo                                 Mujeres
# Nivel de formacion    2ª etapa E. Secundaria
# periodo                                 2018
# Total                                     ..
# dtype: object

# %%
df_niv_est_hom.tail()
# Out:
#      Grupo de edad Comunidad autonoma     Sexo Nivel de formacion  periodo  \
# 3757  55 - 64 años          - Melilla  Hombres        E. Superior     2022
# 3758  55 - 64 años          - Melilla  Hombres        E. Superior     2021
# 3759  55 - 64 años          - Melilla  Hombres        E. Superior     2020
# 3760  55 - 64 años          - Melilla  Hombres        E. Superior     2019
# 3761  55 - 64 años          - Melilla  Hombres        E. Superior     2018
#
#      Total
# 3757    ..
# 3758    ..
# 3759    ..
# 3760    ..
# 3761    ..

# %% [markdown]
# ## Aquí se ordenan los datos para las gráficas de acontinuación:

# %%
df_abandono_l_hom.sort_values(by='periodo', ascending= False, inplace=True, na_position='last')
df_abandono_l_muj.sort_values(by='periodo', ascending= False, inplace=True, na_position='last')
df_niv_est_hom.sort_values(by='periodo', ascending= False, inplace=True, na_position='last')
df_niv_est_muj.sort_values(by='periodo', ascending= False, inplace=True, na_position='last')
# Out:
# C:\Users\Ro\AppData\Local\Temp\ipykernel_21472\3351406147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_abandono_l_hom.sort_values(by='periodo', ascending= False, inplace=True, na_position='last')
# C:\Users\Ro\AppData\Local\Temp\ipykernel_21472\3351406147.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_abandono_l_muj.sort_values(by='periodo', ascending= False, inplace=True, na_position='last')
# C:\Users\Ro\AppData\Local\Temp\ipykernel_21472\3351406147.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# ## Graficas:
#
# Grafica sobre abandonos de estudios y nivel formativo superior

# %%
x = df_abandono_l.head(5)
y = df_abandono_l_hom.head(5)
z =df_abandono_l_muj.head(5)

plt.bar(x['periodo'], x['Total'],color='grey')
plt.title("Top 5 años con mas abandonos en los estudios")
plt.xlabel("Periodo en los que la gente dejo sus estudios con una mayor frecuencia")
plt.ylabel("Total de abandonos")
plt.show()

# %%
df_niv_est['Nivel de formacion'].hist(color='lightgrey')
# Out:
# <Axes: >

# %%
sns.violinplot(x='Sexo', y='periodo', data=df_niv_est, inner=None, palette='pastel')
plt.title("Gráfica de Violín por sexo y periodo")
plt.xlabel("Sexo")
plt.ylabel("Periodo")
plt.show()
# Out:
# C:\Users\Ro\AppData\Local\Temp\ipykernel_21472\785094307.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Sexo', y='periodo', data=df_niv_est, inner=None, palette='pastel')

# %%
print(df_niv_est['Grupo de edad'].mode())
# Out:
# 0    25 - 34 años
# 1    25 - 64 años
# 2    35 - 44 años
# 3    45 - 54 años
# 4    55 - 64 años
# Name: Grupo de edad, dtype: object

# %%
# La grafica no tira
v = df_niv_est_hom.head(5)
h = df_abandono_l_hom.head(5)
g =df_abandono_l_muj.head(5)

plt.plot(h['periodo'], v['Nivel de formacion'])
plt.title("Educacion por años")
plt.xlabel("Años")
plt.ylabel("Etapa educativa")
plt.show()

# %%
df_niv_est_muj['Nivel de formacion'].hist(color='pink')
# Out:
# <Axes: >

# %%
df_niv_est_muj.sort_values(by='Grupo de edad', ascending= True, inplace=True, na_position='last')
df_niv_est_muj['Grupo de edad'].hist(color = 'pink')
# Out:
# C:\Users\Ro\AppData\Local\Temp\ipykernel_21472\2900010224.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_niv_est_muj.sort_values(by='Grupo de edad', ascending= True, inplace=True, na_position='last')
# <Axes: >

# %%
df_niv_est_muj['Nivel de formacion'].hist(color='skyblue')
# Out:
# <Axes: >

# %%
df_niv_est_hom.sort_values(by='Grupo de edad', ascending= True, inplace=True, na_position='last')
df_niv_est_muj['Grupo de edad'].hist(color = 'skyblue')
# Out:
# C:\Users\Ro\AppData\Local\Temp\ipykernel_21472\2897938950.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_niv_est_hom.sort_values(by='Grupo de edad', ascending= True, inplace=True, na_position='last')
# <Axes: >

# %%
df_abandono_l_hom.sort_values(by='periodo', ascending= True, inplace=True, na_position='last')
df_abandono_l_hom['periodo'].hist(color = 'skyblue')
# Out:
# C:\Users\Ro\AppData\Local\Temp\ipykernel_21472\2988725549.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_abandono_l_hom.sort_values(by='periodo', ascending= True, inplace=True, na_position='last')
# <Axes: >

# %%
df_abandono_l_muj.sort_values(by='periodo', ascending= True, inplace=True, na_position='last')
df_abandono_l_muj['periodo'].hist(color = 'skyblue')
# Out:
# C:\Users\Ro\AppData\Local\Temp\ipykernel_21472\1295983240.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_abandono_l_muj.sort_values(by='periodo', ascending= True, inplace=True, na_position='last')
# <Axes: >
