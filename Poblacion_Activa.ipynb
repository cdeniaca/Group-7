# %%
# Importamos pandas y numpy
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
#Expecificamos ruta

url = r'C:\Users\crist\OneDrive\Escritorio\Poblacion_Activa.csv'

# %%
#Cargamos el df

población_activa_df = pd.read_csv(url, sep=';')

# %%
#Imprimimos el df

print(población_activa_df)
# Out:
#       Comunidad autónoma Relación con la actividad en el trimestre actual  \
# 0         Total Nacional                         Total (trimestre actual)
# 1         Total Nacional                         Total (trimestre actual)
# 2         Total Nacional                         Total (trimestre actual)
# 3         Total Nacional                         Total (trimestre actual)
# 4         Total Nacional                         Total (trimestre actual)
# ...                  ...                                              ...
# 30795         19 Melilla                     Inactivos (trimestre actual)
# 30796         19 Melilla                     Inactivos (trimestre actual)
# 30797         19 Melilla                     Inactivos (trimestre actual)
# 30798         19 Melilla                     Inactivos (trimestre actual)
# 30799         19 Melilla                     Inactivos (trimestre actual)
#
#       Relación con la actividad en el trimestre anterior Periodo     Total
# 0                             Total (trimestre anterior)  2024T2    41.497
# 1                             Total (trimestre anterior)  2024T1  41.326,5
# 2                             Total (trimestre anterior)  2023T4  41.221,1
# 3                             Total (trimestre anterior)  2023T3  41.057,1
# 4                             Total (trimestre anterior)  2023T2  40.891,5
# ...                                                  ...     ...       ...
# 30795                     No consta (trimestre anterior)  2006T2        ..
# 30796                     No consta (trimestre anterior)  2006T1        ..
# 30797                     No consta (trimestre anterior)  2005T4       0,1
# 30798                     No consta (trimestre anterior)  2005T3       0,1
# 30799                     No consta (trimestre anterior)  2005T2       0,4
#
# [30800 rows x 5 columns]

# %%
# Muestra los tipos de datos de cada columna
print(población_activa_df.dtypes)
# Out:
# Comunidad autónoma                                    object
# Relación con la actividad en el trimestre actual      object
# Relación con la actividad en el trimestre anterior    object
# Periodo                                               object
# Total                                                 object
# dtype: object

# %%
# Reemplazamos el punto por una cadena vacía para eliminar el separador de miles
población_activa_df['Total'] = población_activa_df['Total'].str.replace('.', '', regex=False)

# Reemplazamos la coma por un punto para que pandas pueda interpretarlo como decimal
población_activa_df['Total'] = población_activa_df['Total'].str.replace(',', '.', regex=False)

# %%
# Convertimos la columna a tipo numérico
población_activa_df['Total'] = pd.to_numeric(población_activa_df['Total'], errors='coerce')

# Verificamos el resultado
print(población_activa_df['Total'].head())
# Out:
# 0    41497.0
# 1    41326.5
# 2    41221.1
# 3    41057.1
# 4    40891.5
# Name: Total, dtype: float64

# %%
# Asegúrate de que la columna 'Total' exista en tu DataFrame
if 'Total' in población_activa_df.columns:
    población_activa_df['Total'] = población_activa_df['Total'] * 1000
else:
    print("La columna 'Total' no se encuentra en el DataFrame.")

# %%
# Crear una columna 'AÑO' con los primeros 4 caracteres de 'Periodo'
población_activa_df['AÑO'] = población_activa_df['Periodo'].str[:4]

# Crear una columna 'Trimestre' con los caracteres restantes de 'Periodo'
población_activa_df['Trimestre'] = población_activa_df['Periodo'].str[4:]

# Crear una columna 'Trimestre' con los caracteres restantes de 'Tip'

# %%
# Filtrar el DataFrame para que solo contenga los años de 2018 a 2023
años_filtrados = ['2018', '2019', '2020', '2021', '2022', '2023']
población_activa_df = población_activa_df[
    población_activa_df['AÑO'].isin(años_filtrados) &
    (población_activa_df['Comunidad autónoma'] != 'Total Nacional') &
    (población_activa_df['Relación con la actividad en el trimestre actual'] != 'Total (trimestre actual)') &
    (población_activa_df['Relación con la actividad en el trimestre anterior'] == 'Total (trimestre anterior)')
]

# %%
población_activa_df
# Out:
#       Comunidad autónoma Relación con la actividad en el trimestre actual  \
# 1927        01 Andalucía                      Ocupados (trimestre actual)
# 1928        01 Andalucía                      Ocupados (trimestre actual)
# 1929        01 Andalucía                      Ocupados (trimestre actual)
# 1930        01 Andalucía                      Ocupados (trimestre actual)
# 1931        01 Andalucía                      Ocupados (trimestre actual)
# ...                  ...                                              ...
# 30436         19 Melilla                     Inactivos (trimestre actual)
# 30437         19 Melilla                     Inactivos (trimestre actual)
# 30438         19 Melilla                     Inactivos (trimestre actual)
# 30439         19 Melilla                     Inactivos (trimestre actual)
# 30440         19 Melilla                     Inactivos (trimestre actual)
#
#       Relación con la actividad en el trimestre anterior Periodo      Total  \
# 1927                          Total (trimestre anterior)  2023T4  3402300.0
# 1928                          Total (trimestre anterior)  2023T3  3390500.0
# 1929                          Total (trimestre anterior)  2023T2  3396200.0
# 1930                          Total (trimestre anterior)  2023T1  3346400.0
# 1931                          Total (trimestre anterior)  2022T4  3280300.0
# ...                                                  ...     ...        ...
# 30436                         Total (trimestre anterior)  2019T1    24000.0
# 30437                         Total (trimestre anterior)  2018T4    26400.0
# 30438                         Total (trimestre anterior)  2018T3    22600.0
# 30439                         Total (trimestre anterior)  2018T2    22900.0
# 30440                         Total (trimestre anterior)  2018T1    25400.0
#
#         AÑO Trimestre
# 1927   2023        T4
# 1928   2023        T3
# 1929   2023        T2
# 1930   2023        T1
# 1931   2022        T4
# ...     ...       ...
# 30436  2019        T1
# 30437  2018        T4
# 30438  2018        T3
# 30439  2018        T2
# 30440  2018        T1
#
# [1368 rows x 7 columns]

# %%
población_activa_df
# Out:
#       Comunidad autónoma Relación con la actividad en el trimestre actual  \
# 1927        01 Andalucía                      Ocupados (trimestre actual)
# 1928        01 Andalucía                      Ocupados (trimestre actual)
# 1929        01 Andalucía                      Ocupados (trimestre actual)
# 1930        01 Andalucía                      Ocupados (trimestre actual)
# 1931        01 Andalucía                      Ocupados (trimestre actual)
# ...                  ...                                              ...
# 30436         19 Melilla                     Inactivos (trimestre actual)
# 30437         19 Melilla                     Inactivos (trimestre actual)
# 30438         19 Melilla                     Inactivos (trimestre actual)
# 30439         19 Melilla                     Inactivos (trimestre actual)
# 30440         19 Melilla                     Inactivos (trimestre actual)
#
#       Relación con la actividad en el trimestre anterior Periodo      Total  \
# 1927                          Total (trimestre anterior)  2023T4  3402300.0
# 1928                          Total (trimestre anterior)  2023T3  3390500.0
# 1929                          Total (trimestre anterior)  2023T2  3396200.0
# 1930                          Total (trimestre anterior)  2023T1  3346400.0
# 1931                          Total (trimestre anterior)  2022T4  3280300.0
# ...                                                  ...     ...        ...
# 30436                         Total (trimestre anterior)  2019T1    24000.0
# 30437                         Total (trimestre anterior)  2018T4    26400.0
# 30438                         Total (trimestre anterior)  2018T3    22600.0
# 30439                         Total (trimestre anterior)  2018T2    22900.0
# 30440                         Total (trimestre anterior)  2018T1    25400.0
#
#         AÑO Trimestre
# 1927   2023        T4
# 1928   2023        T3
# 1929   2023        T2
# 1930   2023        T1
# 1931   2022        T4
# ...     ...       ...
# 30436  2019        T1
# 30437  2018        T4
# 30438  2018        T3
# 30439  2018        T2
# 30440  2018        T1
#
# [1368 rows x 7 columns]

# %%
# Contar las filas duplicadas
duplicados = población_activa_df.duplicated().sum()
print(f"Número de filas duplicadas: {duplicados}")
# Out:
# Número de filas duplicadas: 0

# %%
# Contar los valores nulos en cada columna
nulos = población_activa_df.isnull().sum()
print("Número de valores nulos en cada columna:")
print(nulos)
# Out:
# Número de valores nulos en cada columna:
# Comunidad autónoma                                    0
# Relación con la actividad en el trimestre actual      0
# Relación con la actividad en el trimestre anterior    0
# Periodo                                               0
# Total                                                 0
# AÑO                                                   0
# Trimestre                                             0
# dtype: int64

# %%
# Filtrar las filas que tienen al menos un valor nulo
filas_nulas = población_activa_df[población_activa_df.isnull().any(axis=1)]

# Mostrar las filas con valores nulos
print("Filas con valores nulos:")
print(filas_nulas)
# Out:
# Filas con valores nulos:
# Empty DataFrame
# Columns: [Comunidad autónoma, Relación con la actividad en el trimestre actual, Relación con la actividad en el trimestre anterior, Periodo, Total, AÑO, Trimestre]
# Index: []

# %%
print(población_activa_df['Comunidad autónoma'].unique())
# Out:
# ['01 Andalucía' '02 Aragón' '03 Asturias, Principado de'
#  '04 Balears, Illes' '05 Canarias' '06 Cantabria' '07 Castilla y León'
#  '08 Castilla - La Mancha' '09 Cataluña' '10 Comunitat Valenciana'
#  '11 Extremadura' '12 Galicia' '13 Madrid, Comunidad de'
#  '14 Murcia, Región de' '15 Navarra, Comunidad Foral de' '16 País Vasco'
#  '17 Rioja, La' '18 Ceuta' '19 Melilla']

# %%
print(población_activa_df['Relación con la actividad en el trimestre actual'].unique())
# Out:
# ['Ocupados (trimestre actual)' 'Parados (trimestre actual)'
#  'Inactivos (trimestre actual)']

# %%
# Comprobar duplicados en las combinaciones de índice
duplicados = población_activa_df.duplicated(subset=['Periodo', 'Comunidad autónoma', 'AÑO', 'Trimestre', 'Relación con la actividad en el trimestre actual'], keep=False)
if duplicados.any():
    print("Hay duplicados en los datos:")
    print(población_activa_df[duplicados])
else:
    print("No hay duplicados, puedes usar pivot() sin problemas.")
# Out:
# No hay duplicados, puedes usar pivot() sin problemas.

# %%
# Eliminar duplicados
población_activa_df = población_activa_df.drop_duplicates(subset=['Periodo', 'Comunidad autónoma', 'AÑO', 'Trimestre', 'Relación con la actividad en el trimestre actual'])

# %%
print(población_activa_df['Relación con la actividad en el trimestre actual'].unique())
# Out:
# ['Ocupados (trimestre actual)' 'Parados (trimestre actual)'
#  'Inactivos (trimestre actual)']

# %%
población_activa_df
# Out:
#       Comunidad autónoma Relación con la actividad en el trimestre actual  \
# 1927        01 Andalucía                      Ocupados (trimestre actual)
# 1928        01 Andalucía                      Ocupados (trimestre actual)
# 1929        01 Andalucía                      Ocupados (trimestre actual)
# 1930        01 Andalucía                      Ocupados (trimestre actual)
# 1931        01 Andalucía                      Ocupados (trimestre actual)
# ...                  ...                                              ...
# 30436         19 Melilla                     Inactivos (trimestre actual)
# 30437         19 Melilla                     Inactivos (trimestre actual)
# 30438         19 Melilla                     Inactivos (trimestre actual)
# 30439         19 Melilla                     Inactivos (trimestre actual)
# 30440         19 Melilla                     Inactivos (trimestre actual)
#
#       Relación con la actividad en el trimestre anterior Periodo      Total  \
# 1927                          Total (trimestre anterior)  2023T4  3402300.0
# 1928                          Total (trimestre anterior)  2023T3  3390500.0
# 1929                          Total (trimestre anterior)  2023T2  3396200.0
# 1930                          Total (trimestre anterior)  2023T1  3346400.0
# 1931                          Total (trimestre anterior)  2022T4  3280300.0
# ...                                                  ...     ...        ...
# 30436                         Total (trimestre anterior)  2019T1    24000.0
# 30437                         Total (trimestre anterior)  2018T4    26400.0
# 30438                         Total (trimestre anterior)  2018T3    22600.0
# 30439                         Total (trimestre anterior)  2018T2    22900.0
# 30440                         Total (trimestre anterior)  2018T1    25400.0
#
#         AÑO Trimestre
# 1927   2023        T4
# 1928   2023        T3
# 1929   2023        T2
# 1930   2023        T1
# 1931   2022        T4
# ...     ...       ...
# 30436  2019        T1
# 30437  2018        T4
# 30438  2018        T3
# 30439  2018        T2
# 30440  2018        T1
#
# [1368 rows x 7 columns]

# %%
# Crear un DataFrame pivotado
df_pivot = pd.pivot_table(
    población_activa_df,
    index=['Periodo', 'Comunidad autónoma', 'AÑO', 'Trimestre'],  # Índices de filas
    columns='Relación con la actividad en el trimestre actual',  # Nuevas columnas
    values='Total',  # Valores a pivotar
    aggfunc='sum',  # Función de agregación
    fill_value=0  # Opcional: reemplaza valores NaN por 0
)

# %%
df_pivot
# Out:
# Relación con la actividad en el trimestre actual       Inactivos (trimestre actual)  \
# Periodo Comunidad autónoma             AÑO  Trimestre
# 2018T1  01 Andalucía                   2018 T1                            2965500.0
#         02 Aragón                      2018 T1                             457300.0
#         03 Asturias, Principado de     2018 T1                             439500.0
#         04 Balears, Illes              2018 T1                             381800.0
#         05 Canarias                    2018 T1                             737400.0
# ...                                                                             ...
# 2023T4  15 Navarra, Comunidad Foral de 2023 T4                             233500.0
#         16 País Vasco                  2023 T4                             815200.0
#         17 Rioja, La                   2023 T4                             115300.0
#         18 Ceuta                       2023 T4                              26000.0
#         19 Melilla                     2023 T4                              29000.0
#
# Relación con la actividad en el trimestre actual       Ocupados (trimestre actual)  \
# Periodo Comunidad autónoma             AÑO  Trimestre
# 2018T1  01 Andalucía                   2018 T1                           2967700.0
#         02 Aragón                      2018 T1                            561100.0
#         03 Asturias, Principado de     2018 T1                            387900.0
#         04 Balears, Illes              2018 T1                            488700.0
#         05 Canarias                    2018 T1                            879500.0
# ...                                                                            ...
# 2023T4  15 Navarra, Comunidad Foral de 2023 T4                            302800.0
#         16 País Vasco                  2023 T4                           1024200.0
#         17 Rioja, La                   2023 T4                            144400.0
#         18 Ceuta                       2023 T4                             26300.0
#         19 Melilla                     2023 T4                             26100.0
#
# Relación con la actividad en el trimestre actual       Parados (trimestre actual)
# Periodo Comunidad autónoma             AÑO  Trimestre
# 2018T1  01 Andalucía                   2018 T1                           975700.0
#         02 Aragón                      2018 T1                            73500.0
#         03 Asturias, Principado de     2018 T1                            68600.0
#         04 Balears, Illes              2018 T1                           103100.0
#         05 Canarias                    2018 T1                           228400.0
# ...                                                                           ...
# 2023T4  15 Navarra, Comunidad Foral de 2023 T4                            30900.0
#         16 País Vasco                  2023 T4                            69800.0
#         17 Rioja, La                   2023 T4                            15500.0
#         18 Ceuta                       2023 T4                            12600.0
#         19 Melilla                     2023 T4                            11200.0
#
# [456 rows x 3 columns]

# %%
población_activa_df
# Out:
#       Comunidad autónoma Relación con la actividad en el trimestre actual  \
# 1927        01 Andalucía                      Ocupados (trimestre actual)
# 1928        01 Andalucía                      Ocupados (trimestre actual)
# 1929        01 Andalucía                      Ocupados (trimestre actual)
# 1930        01 Andalucía                      Ocupados (trimestre actual)
# 1931        01 Andalucía                      Ocupados (trimestre actual)
# ...                  ...                                              ...
# 30436         19 Melilla                     Inactivos (trimestre actual)
# 30437         19 Melilla                     Inactivos (trimestre actual)
# 30438         19 Melilla                     Inactivos (trimestre actual)
# 30439         19 Melilla                     Inactivos (trimestre actual)
# 30440         19 Melilla                     Inactivos (trimestre actual)
#
#       Relación con la actividad en el trimestre anterior Periodo      Total  \
# 1927                          Total (trimestre anterior)  2023T4  3402300.0
# 1928                          Total (trimestre anterior)  2023T3  3390500.0
# 1929                          Total (trimestre anterior)  2023T2  3396200.0
# 1930                          Total (trimestre anterior)  2023T1  3346400.0
# 1931                          Total (trimestre anterior)  2022T4  3280300.0
# ...                                                  ...     ...        ...
# 30436                         Total (trimestre anterior)  2019T1    24000.0
# 30437                         Total (trimestre anterior)  2018T4    26400.0
# 30438                         Total (trimestre anterior)  2018T3    22600.0
# 30439                         Total (trimestre anterior)  2018T2    22900.0
# 30440                         Total (trimestre anterior)  2018T1    25400.0
#
#         AÑO Trimestre
# 1927   2023        T4
# 1928   2023        T3
# 1929   2023        T2
# 1930   2023        T1
# 1931   2022        T4
# ...     ...       ...
# 30436  2019        T1
# 30437  2018        T4
# 30438  2018        T3
# 30439  2018        T2
# 30440  2018        T1
#
# [1368 rows x 7 columns]
